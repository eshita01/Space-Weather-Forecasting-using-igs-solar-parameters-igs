# %% [markdown]
# # data adk

# %%
import pandas as pd
data_cmn = pd.read_csv(r"data adk.csv")

# %%
data_cmn
# Out:
#            MJdatet       Time   PRN      Az    Ele     Lat      Lon   Stec  \
# 0      52947.60764  14.583360     1  295.58  11.09  33.813  253.077  54.49
# 1      52947.60799  14.591693     1  295.75  11.22  33.820  253.162  54.24
# 2      52947.60833  14.600027     1  295.92  11.35  33.826  253.247  54.26
# 3      52947.60868  14.608360     1  296.08  11.48  33.832  253.332  54.41
# 4      52947.60903  14.616693     1  296.25  11.61  33.837  253.415  54.24
# ...            ...        ...   ...     ...    ...     ...      ...    ...
# 21730  52947.92188  22.125041    31   48.19   9.39  36.931  274.976  87.59
# 21731  52947.92222  22.133374    31   48.28   9.22  36.976  275.088  87.58
# 21732  52947.92257  22.141707    31   48.36   9.04  37.020  275.201  87.76
# 21733  52947.92292  22.150041    31   48.45   8.87  37.064  275.316  87.32
# 21734  52947.92327  22.158374    31   48.54   8.70  37.109  275.432  87.45
#
#         Vtec   S4
# 0      21.05  -99
# 1      21.02  -99
# ...

# %% [markdown]
# # setting latitute

# %%
data_adk  = data_cmn[data_cmn[' Lat'].between(26.21,26.9,inclusive =True)]

# %%
data_adk
# Out:
#            MJdatet       Time   PRN      Az    Ele     Lat      Lon   Stec  \
# 581    52947.81007  19.441702     1  169.88  44.49  26.878  264.996  76.40
# 582    52947.81042  19.450036     1  169.91  44.24  26.853  264.999  76.73
# 583    52947.81077  19.458369     1  169.93  43.99  26.829  265.003  77.06
# 584    52947.81111  19.466702     1  169.96  43.74  26.804  265.006  77.41
# 585    52947.81146  19.475036     1  169.98  43.49  26.779  265.009  77.77
# ...            ...        ...   ...     ...    ...     ...      ...    ...
# 21252  52947.75486  18.116700    31  157.41  41.59  26.778  265.814  71.48
# 21253  52947.75521  18.125033    31  157.25  41.81  26.803  265.813  71.23
# 21254  52947.75556  18.133366    31  157.10  42.03  26.828  265.812  70.94
# 21255  52947.75590  18.141700    31  156.95  42.25  26.853  265.811  70.71
# 21256  52947.75625  18.150033    31  156.79  42.47  26.877  265.810  70.48
#
#         Vtec   S4
# 581    57.34  -99
# 582    57.38  -99
# ...

# %% [markdown]
# # Filteration of data

# %%
data_adk = data_adk[data_adk[' Stec']>0]

# %%
data_adk  = data_adk[data_adk[' Vtec']>0]

# %%
data_adk
# Out:
#            MJdatet       Time   PRN      Az    Ele     Lat      Lon   Stec  \
# 581    52947.81007  19.441702     1  169.88  44.49  26.878  264.996  76.40
# 582    52947.81042  19.450036     1  169.91  44.24  26.853  264.999  76.73
# 583    52947.81077  19.458369     1  169.93  43.99  26.829  265.003  77.06
# 584    52947.81111  19.466702     1  169.96  43.74  26.804  265.006  77.41
# 585    52947.81146  19.475036     1  169.98  43.49  26.779  265.009  77.77
# ...            ...        ...   ...     ...    ...     ...      ...    ...
# 21252  52947.75486  18.116700    31  157.41  41.59  26.778  265.814  71.48
# 21253  52947.75521  18.125033    31  157.25  41.81  26.803  265.813  71.23
# 21254  52947.75556  18.133366    31  157.10  42.03  26.828  265.812  70.94
# 21255  52947.75590  18.141700    31  156.95  42.25  26.853  265.811  70.71
# 21256  52947.75625  18.150033    31  156.79  42.47  26.877  265.810  70.48
#
#         Vtec   S4
# 581    57.34  -99
# 582    57.38  -99
# ...

# %% [markdown]
# # Plots

# %%
import matplotlib.pyplot as plt
plt.scatter(data_adk.MJdatet,data_adk[' Stec'])

# %%
import matplotlib.pyplot as plt
plt.scatter(data_adk.MJdatet,data_adk[' Vtec'])

# %% [markdown]
# # Data arp

# %%
data_arp = pd.read_csv(r"data arp.csv")

# %%
data_arp = data_arp[data_arp[' Stec']>0]

# %%
data_arp = data_arp[data_arp[' Vtec']>0]

# %%
data_arp
# Out:
#            MJdatet       Time   PRN      Az    Ele     Lat      Lon   Stec  \
# 0      52947.66528  15.966682     1  322.57  35.34  30.992  260.101  42.35
# 1      52947.66563  15.975015     1  322.72  35.52  30.981  260.127  42.33
# 2      52947.66597  15.983348     1  322.87  35.69  30.969  260.153  42.21
# 3      52947.66632  15.991682     1  323.02  35.86  30.958  260.178  42.16
# 4      52947.66667  16.000015     1  323.16  36.03  30.946  260.204  42.13
# ...            ...        ...   ...     ...    ...     ...      ...    ...
# 13522  52947.91424  21.941692    31   45.51  10.89  34.917  272.093  88.06
# 13523  52947.91458  21.950026    31   45.59  10.71  34.965  272.189  87.93
# 13524  52947.91493  21.958359    31   45.66  10.53  35.013  272.287  87.91
# 13525  52947.91528  21.966693    31   45.74  10.36  35.061  272.386  87.98
# 13526  52947.91563  21.975026    31   45.81  10.18  35.110  272.486  87.95
#
#         Vtec   S4
# 0      24.46  -99
# 1      24.54  -99
# ...

# %%
data_arp = data_arp[data_arp[' Lat'].between(26.0,26.9,inclusive =True)]

# %%
import julian
import datetime

mjd = 52947.79028
dt = julian.from_jd(mjd, fmt='mjd')
print(dt)
# Out:
# 2003-11-04 18:58:00.191986

# %%
data_arp.columns
# Out:
# Index(['MJdatet', ' Time', ' PRN', ' Az', ' Ele', ' Lat', ' Lon', ' Stec',
#        ' Vtec', ' S4'],
#       dtype='object')

# %%
# import pandas_bokeh
# pandas_bokeh.output_file("plot.html")
# data_arp.plot_bokeh(kind ="cirle",x ='MJdatet', y = ' Stec',rangetool = True)

# %%
import matplotlib.pyplot as plt
plt.scatter(data_arp.MJdatet,data_arp[' Stec'])

# %%
import matplotlib.pyplot as plt
plt.scatter(data_arp.MJdatet,data_arp[' Vtec'])

# %% [markdown]
# # Merging data

# %%
frames = [data_adk,data_arp]
fina_data = pd.concat(frames)

# %%
fina_data
# Out:
#            MJdatet       Time   PRN      Az    Ele     Lat      Lon   Stec  \
# 581    52947.81007  19.441702     1  169.88  44.49  26.878  264.996  76.40
# 582    52947.81042  19.450036     1  169.91  44.24  26.853  264.999  76.73
# 583    52947.81077  19.458369     1  169.93  43.99  26.829  265.003  77.06
# 584    52947.81111  19.466702     1  169.96  43.74  26.804  265.006  77.41
# 585    52947.81146  19.475036     1  169.98  43.49  26.779  265.009  77.77
# ...            ...        ...   ...     ...    ...     ...      ...    ...
# 12533  52947.96806  23.233362    29  260.57  15.85  26.161  253.729  78.07
# 12534  52947.96840  23.241696    29  260.35  15.76  26.122  253.701  78.13
# 12535  52947.96875  23.250029    29  260.14  15.67  26.083  253.672  78.22
# 12536  52947.96910  23.258362    29  259.92  15.57  26.044  253.643  78.22
# 12537  52947.96945  23.266696    29  259.71  15.48  26.004  253.614  78.25
#
#         Vtec   S4
# 581    57.34  -99
# 582    57.38  -99
# ...

# %% [markdown]
# # Plots for concatenated data

# %%
import matplotlib.pyplot as plt
plt.scatter(fina_data.MJdatet,fina_data[' Vtec'])

# %%
import matplotlib.pyplot as plt
plt.scatter(fina_data.MJdatet,fina_data[' Stec'])

# %%
import julian
def jd_cal(mjd):
    dt = julian.from_jd(mjd, fmt='mjd')
    return dt

# %%
fina_data.columns
# Out:
# Index(['MJdatet', ' Time', ' PRN', ' Az', ' Ele', ' Lat', ' Lon', ' Stec',
#        ' Vtec', ' S4'],
#       dtype='object')

# %% [markdown]
# # Conversion of JT TO UT

# %%
fina_data['Time'] = fina_data.apply(lambda x :jd_cal(x['MJdatet']),axis=1)

# %%
fina_data
# Out:
#            MJdatet       Time   PRN      Az    Ele     Lat      Lon   Stec  \
# 581    52947.81007  19.441702     1  169.88  44.49  26.878  264.996  76.40
# 582    52947.81042  19.450036     1  169.91  44.24  26.853  264.999  76.73
# 583    52947.81077  19.458369     1  169.93  43.99  26.829  265.003  77.06
# 584    52947.81111  19.466702     1  169.96  43.74  26.804  265.006  77.41
# 585    52947.81146  19.475036     1  169.98  43.49  26.779  265.009  77.77
# ...            ...        ...   ...     ...    ...     ...      ...    ...
# 12533  52947.96806  23.233362    29  260.57  15.85  26.161  253.729  78.07
# 12534  52947.96840  23.241696    29  260.35  15.76  26.122  253.701  78.13
# 12535  52947.96875  23.250029    29  260.14  15.67  26.083  253.672  78.22
# 12536  52947.96910  23.258362    29  259.92  15.57  26.044  253.643  78.22
# 12537  52947.96945  23.266696    29  259.71  15.48  26.004  253.614  78.25
#
#         Vtec   S4                       Time
# ...

# %%
# %matplotlib
import matplotlib.pyplot as plt
plt.scatter(fina_data.Time,fina_data[' Stec'])
# Out:
# Using matplotlib backend: Qt5Agg

# %%
fina_data[' Lon'].value_counts()
# Out:
# 262.336    20
# 262.335     6
# 262.333     4
# 262.334     4
# 262.330     3
#            ..
# 254.793     1
# 258.070     1
# 260.868     1
# 263.466     1
# 258.000     1
# Name:  Lon, Length: 1535, dtype: int64

# %% [markdown]
# # Setting longitute

# %%
londata = fina_data[fina_data[' Lon'] ==262.336]

# %%
londata
# Out:
#           MJdatet       Time   PRN      Az    Ele     Lat      Lon   Stec  \
# 6544  52947.82431  19.783355    13  199.93  61.72  26.341  262.336  56.91
# 6545  52947.82465  19.791688    13  199.73  61.48  26.324  262.336  57.35
# 6546  52947.82500  19.800021    13  199.52  61.23  26.306  262.336  57.76
# 6547  52947.82535  19.808355    13  199.32  60.99  26.289  262.336  58.18
# 6548  52947.82570  19.816688    13  199.12  60.74  26.272  262.336  58.59
# 6549  52947.82604  19.825021    13  198.93  60.50  26.254  262.336  58.89
# 6550  52947.82639  19.833355    13  198.74  60.25  26.237  262.336  59.19
# 6551  52947.82674  19.841688    13  198.55  60.00  26.219  262.336  59.49
# 6552  52947.82708  19.850021    13  198.36  59.76  26.202  262.336  59.77
# 6553  52947.82743  19.858355    13  198.18  59.51  26.184  262.336  60.06
# 6554  52947.82778  19.866688    13  198.00  59.26  26.167  262.336  60.37
# 6555  52947.82813  19.875022    13  197.83  59.02  26.149  262.336  60.71
# ...

# %% [markdown]
# # Plots for fixed Longitute

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(londata.Time,londata[' Stec'])
plt.xticks(rotation = 45)
# Out:
# (array([12360.82430556, 12360.825     , 12360.82569444, 12360.82638889,
#         12360.82708333, 12360.82777778, 12360.82847222, 12360.82916667,
#         12360.82986111, 12360.83055556]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
plt.scatter(londata.Time,londata[' Vtec'])
plt.xticks(rotation = 45)
# Out:
# (array([12360.82430556, 12360.825     , 12360.82569444, 12360.82638889,
#         12360.82708333, 12360.82777778, 12360.82847222, 12360.82916667,
#         12360.82986111, 12360.83055556]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Aira data

# %%
import pandas as pd
data_aira= pd.read_csv(r"data aira.csv")

# %%
data_aira
# Out:
#            Mjdatet       Time   PRN      Az    Ele     Lat      Lon   Stec  \
# 0      52947.17257   4.141666     1  321.31  12.60  39.169  122.784  76.67
# 1      52947.17292   4.150000     1  321.27  12.78  39.103  122.851  76.35
# 2      52947.17326   4.158333     1  321.22  12.97  39.039  122.917  76.04
# 3      52947.17361   4.166666     1  321.18  13.15  38.975  122.981  75.80
# 4      52947.17396   4.175000     1  321.13  13.33  38.911  123.045  75.40
# ...            ...        ...   ...     ...    ...     ...      ...    ...
# 21090  52947.52847  12.683333    31  114.52   5.60  25.363  144.453  23.29
# 21091  52947.52882  12.691666    31  114.66   5.46  25.278  144.532  23.29
# 21092  52947.52917  12.700000    31  114.81   5.32  25.193  144.611  23.29
# 21093  52947.52951  12.708333    31  114.96   5.17  25.107  144.690  23.29
# 21094  52947.52986  12.716666    31  115.10   5.03  25.020  144.771  23.29
#
#         Vtec   S4
# 0      27.11  -99
# 1      27.11  -99
# ...

# %%
data_aira = data_aira[data_aira[' Stec']>0]

# %%
data_aira = data_aira[data_aira[' Vtec']>0]

# %%
data_aira = data_aira[data_aira[' Lat'].between(26.0,26.9,inclusive =True)]

# %%
data_aira.columns
# Out:
# Index(['Mjdatet', ' Time', ' PRN', ' Az', ' Ele', ' Lat', ' Lon', ' Stec',
#        ' Vtec', ' S4'],
#       dtype='object')

# %%
data_aira['Time'] = data_aira.apply(lambda x :jd_cal(x['Mjdatet']),axis=1)

# %%
data_aira
# Out:
#            Mjdatet       Time   PRN      Az    Ele     Lat      Lon   Stec  \
# 428    52947.32118   7.708333     1  228.15  19.47  26.893  124.607  85.75
# 429    52947.32153   7.716666     1  227.97  19.31  26.844  124.587  85.75
# 430    52947.32188   7.725000     1  227.80  19.15  26.795  124.568  85.75
# 431    52947.32222   7.733333     1  227.62  18.99  26.745  124.548  85.75
# 432    52947.32257   7.741666     1  227.45  18.83  26.695  124.528  85.75
# ...            ...        ...   ...     ...    ...     ...      ...    ...
# 21078  52947.52431  12.583333    31  112.71   7.33  26.310  143.550  21.54
# 21079  52947.52465  12.591666    31  112.86   7.19  26.235  143.622  21.99
# 21080  52947.52500  12.600000    31  113.01   7.04  26.160  143.695  21.92
# 21081  52947.52535  12.608333    31  113.17   6.90  26.084  143.769  22.28
# 21082  52947.52569  12.616666    31  113.32   6.76  26.007  143.843  22.28
#
#         Vtec   S4                       Time
# ...

# %% [markdown]
# # Problem of less values in some cmn

# %%
data_aira[' Lon'].value_counts()
# Out:
# 131.059    2
# 127.115    2
# 128.146    2
# 128.189    2
# 128.297    2
#           ..
# 142.935    1
# 127.179    1
# 136.600    1
# 127.075    1
# 127.171    1
# Name:  Lon, Length: 531, dtype: int64

# %% [markdown]
# # Hydrebad station 19 october

# %%
import julian
def jd_cal(mjd):
    dt = julian.from_jd(mjd, fmt='mjd')
    return dt

# %%
import pandas as pd
data_chur = pd.read_csv(r"D:\Documents\Data IIT\19 october 2003\data\chur canada.csv")

# %%
data_chur
# Out:
#            MJdatet       Time   PRN     Az    Ele     Lat      Lon   Stec  \
# 0      52931.15694   3.766667     1  62.57  10.30  62.211  286.895  14.33
# 1      52931.15729   3.775000     1  62.40  10.42  62.233  286.749  13.88
# 2      52931.15764   3.783333     1  62.23  10.54  62.254  286.605  14.43
# 3      52931.15799   3.791667     1  62.06  10.66  62.275  286.463  15.13
# 4      52931.15833   3.800000     1  61.88  10.77  62.295  286.321  14.14
# ...            ...        ...   ...    ...    ...     ...      ...    ...
# 24176  52931.99583  23.900000    31  65.66  11.01  61.594  286.288   9.87
# 24177  52931.99618  23.908333    31  65.71  10.81  61.597  286.498   9.84
# 24178  52931.99653  23.916667    31  65.75  10.61  61.600  286.712  10.29
# 24179  52931.99688  23.925000    31  65.80  10.42  61.602  286.928  10.76
# 24180  52931.99722  23.933333    31  65.84  10.22  61.604  287.146  10.78
#
#         Vtec   S4
# 0       4.82  -99
# 1       4.67  -99
# 2       4.88  -99
# ...

# %%
data_chur['Time'] = data_chur.apply(lambda x :jd_cal(x['MJdatet']),axis=1)

# %%
data_chur
# Out:
#            MJdatet       Time   PRN     Az    Ele     Lat      Lon   Stec  \
# 0      52931.15694   3.766667     1  62.57  10.30  62.211  286.895  14.33
# 1      52931.15729   3.775000     1  62.40  10.42  62.233  286.749  13.88
# 2      52931.15764   3.783333     1  62.23  10.54  62.254  286.605  14.43
# 3      52931.15799   3.791667     1  62.06  10.66  62.275  286.463  15.13
# 4      52931.15833   3.800000     1  61.88  10.77  62.295  286.321  14.14
# ...            ...        ...   ...    ...    ...     ...      ...    ...
# 24176  52931.99583  23.900000    31  65.66  11.01  61.594  286.288   9.87
# 24177  52931.99618  23.908333    31  65.71  10.81  61.597  286.498   9.84
# 24178  52931.99653  23.916667    31  65.75  10.61  61.600  286.712  10.29
# 24179  52931.99688  23.925000    31  65.80  10.42  61.602  286.928  10.76
# 24180  52931.99722  23.933333    31  65.84  10.22  61.604  287.146  10.78
#
#         Vtec   S4                       Time
# ...

# %%
data_chur = data_chur[data_chur[' Stec']>0]
data_chur = data_chur[data_chur[' Vtec']>0]
data_chur = data_chur[data_chur[' Ele']>20]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(data_chur.Time,data_chur[' Stec'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
data_nlib = pd.read_csv(r"D:\Documents\Data IIT\19 october 2003\data\nlib.csv")
data_glps = pd.read_csv(r"D:\Documents\Data IIT\19 october 2003\data\glps.csv")

# %%
data_nlib['Time'] = data_nlib.apply(lambda x :jd_cal(x['MJdatet']),axis=1)
data_glps['Time'] = data_glps.apply(lambda x :jd_cal(x['MJdatet']),axis=1)

# %%
data_nlib
# Out:
#            MJdatet       Time   PRN      Az    Ele     Lat      Lon   Stec  \
# 0      52931.64306  15.433333     1  288.12   8.23  44.414  252.347  33.60
# 1      52931.64340  15.441667     1  288.25   8.39  44.430  252.486  33.74
# 2      52931.64375  15.450000     1  288.39   8.55  44.446  252.623  33.72
# 3      52931.64792  15.550000     1  290.01  10.47  44.594  254.178  34.69
# 4      52931.64861  15.566667     1  290.28  10.79  44.612  254.422  34.82
# ...            ...        ...   ...     ...    ...     ...      ...    ...
# 18908  52931.98368  23.608333    31   58.05  10.72  46.676  281.599  13.29
# 18909  52931.98403  23.616667    31   58.13  10.54  46.697  281.733  13.09
# 18910  52931.98438  23.625000    31   58.22  10.36  46.718  281.868  12.91
# 18911  52931.98472  23.633333    31   58.31  10.18  46.739  282.005  12.69
# 18912  52931.98611  23.666667    31   58.66   9.47  46.821  282.571  12.69
#
#         Vtec   S4                       Time
# ...

# %%
data_glps
# Out:
#            MJdatet       Time   PRN      Az   Ele     Lat      Lon    Stec  \
# 0      52931.71875  17.250000     1  333.78  8.15  10.070  264.314  130.49
# 1      52931.71910  17.258333     1  333.91  8.28  10.007  264.376  130.59
# 2      52931.71944  17.266667     1  334.04  8.42   9.944  264.437  130.72
# 3      52931.71979  17.275000     1  334.16  8.56   9.882  264.498  130.85
# 4      52931.72014  17.283333     1  334.29  8.70   9.819  264.559  130.99
# ...            ...        ...   ...     ...   ...     ...      ...     ...
# 27783  52931.92569  22.216667    31   29.47  7.75   9.958  275.810  172.63
# 27784  52931.92604  22.225000    31   29.56  7.58  10.041  275.880  172.63
# 27785  52931.92639  22.233333    31   29.64  7.42  10.125  275.951  172.63
# 27786  52931.92674  22.241667    31   29.73  7.25  10.209  276.023  172.63
# 27787  52931.92708  22.250000    31   29.82  7.08  10.293  276.095  172.63
#
#         Vtec   S4                       Time
# ...

# %%
data_nlib = data_nlib[data_nlib[' Stec']>0]
data_nlib = data_nlib[data_nlib[' Vtec']>0]
data_nlib = data_nlib[data_nlib[' Ele']>20]

# %%
data_glps = data_glps[data_glps[' Stec']>0]
data_glps = data_glps[data_glps[' Vtec']>0]
data_glps = data_glps[data_glps[' Ele']>20]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(data_nlib.Time,data_nlib[' Stec'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(data_glps.Time,data_glps[' Stec'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# import pandas as pd
# data_canada = pd.read_csv(r"D:\Documents\Data IIT\19 october 2003\whit canda.csv")

# %%
# import pandas as pd
# data_france = pd.read_csv(r"D:\Documents\Data IIT\19 october 2003\brst.csv")

# %%
# data_canada

# %%
# data_france

# %%
# import julian
# def jd_cal(mjd):
#     dt = julian.from_jd(mjd, fmt='mjd')
#     return dt

# data_canada['UTC Time'] = data_canada.apply(lambda x :jd_cal(x['Mjdatet']),axis=1)

# %%
# data_france['UTC Time'] = data_france.apply(lambda x :jd_cal(x['MJdatet']),axis=1)

# %%
# data_canada

# %%
# data_canada['UTC Time']

# %%
# data_canada.to_csv("out.csv")

# %%
# data_france

# %%
# data_france.to_csv("out1.csv")

# %%
# data_canada = data_canada[data_canada[' Stec']>0]
# data_canada = data_canada[data_canada[' Vtec']>0]
# data_canada = data_canada[data_canada[' Ele']>20]

# %%
#data_france = data_france[data_france[' Stec']>0]
#data_france = data_france[data_france[' Vtec']>0]
#data_france = data_france[data_france[' Ele']>20]

# %%
# data_france

# %%
# data_canada

# %%
# data_canda = data_canada.iloc[:.10000]

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt
# plt.scatter(data_canada['UTC Time'],data_canada[' Stec'])
# plt.xticks(rotation = 45)

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt
# plt.scatter(data_france['UTC Time'],data_france[' Stec'])
# plt.xticks(rotation = 45)

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt
# plt.scatter(data_france['Time'],data_france[' Stec'])
# plt.xticks(rotation = 45)

# %%
data_chur['UTC Time'] = data_chur.apply(lambda x :jd_cal(x['MJdatet']),axis=1
                                       )

# %%
data_glps['UTC Time'] = data_glps.apply(lambda x :jd_cal(x['MJdatet']),axis=1)
data_nlib['UTC Time'] = data_nlib.apply(lambda x :jd_cal(x['MJdatet']),axis=1)

# %%
data_chur.index =  data_chur['UTC Time']
data_chur = data_chur.drop(columns=['UTC Time'])

# %%
data_glps.index =  data_glps['UTC Time']
data_glps = data_glps.drop(columns=['UTC Time'])

# %%
data_nlib.index =  data_nlib['UTC Time']
data_nlib = data_nlib.drop(columns=['UTC Time'])

# %%
data_canada = data_chur.resample("1h").mean()
data_eq = data_glps.resample("1h").mean()
data_us = data_nlib.resample("1h").mean()

# %%
# import matplotlib.pyplot as plt
# plt.plot(data_c[' Vtec'])
# plt.xticks(rotation = 45)

# %%
# data_france.index =  data_france['UTC Time']
# data_france = data_france.drop(columns=['UTC Time'])

# %%
# data_france

# %%
# data_f = data_france.resample("1h").mean()

# %%
# data_f

# %%
# import matplotlib.pyplot as plt
# plt.plot(data_f[' Vtec'])
# plt.xticks(rotation = 45)

# %%
data_canada.corrwith(data_eq, axis = 0)
# Out:
# MJdatet    0.999977
#  Time      0.999971
#  PRN       0.119635
#  Az        0.321144
#  Ele      -0.065637
#  Lat      -0.211338
#  Lon       0.442516
#  Stec      0.783126
#  Vtec      0.768210
#  S4             NaN
# dtype: float64

# %%
data_canada.corrwith(data_us, axis = 0)
# Out:
# MJdatet    0.999949
#  Time      0.999872
#  PRN       0.872230
#  Az        0.552502
#  Ele       0.334042
#  Lat       0.240823
#  Lon       0.376178
#  Stec      0.927228
#  Vtec      0.918313
#  S4             NaN
# dtype: float64

# %%
data_eq.corrwith(data_us, axis = 0)
# Out:
# MJdatet    0.999959
#  Time      0.999898
#  PRN       0.270337
#  Az        0.344157
#  Ele      -0.033245
#  Lat      -0.505693
#  Lon       0.140031
#  Stec      0.902550
#  Vtec      0.913308
#  S4             NaN
# dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(data_eq[' Stec'],data_us[' Stec'])
plt.xticks(rotation = 45)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("omni2_all_years.dat") as f:
    print(f.readline())
# Out:
# 1963   1  0 1771 99 99 999 999 999.9 999.9 999.9 999.9 999.9 999.9 999.9 999.9 999.9 999.9 999.9 999.9 999.9 999.9 9999999. 999.9 9999. 999.9 999.9 9.999 99.99 9999999. 999.9 9999. 999.9 999.9 9.999 999.99 999.99 999.9  7  33    -6  119 999999.99 99999.99 99999.99 99999.99 99999.99 99999.99  0   3 999.9 999.9 99999 99999 99.9

# %%
df = pd.read_csv("omni2_all_years.dat",
                 delim_whitespace=True,
                 usecols=[0, 1, 2, 39, 40, 50],
                 names=["Year", "DOY", "Hour", "R", "Dst", "F10.7"])

# %%
df
# Out:
#         Year  DOY  Hour    R    Dst  F10.7
# 0       1963    1     0   33     -6  999.9
# 1       1963    1     1   33     -5  999.9
# 2       1963    1     2   33     -5  999.9
# 3       1963    1     3   33     -3  999.9
# 4       1963    1     4   33     -3  999.9
# ...      ...  ...   ...  ...    ...    ...
# 517195  2021  365    19  999  99999  999.9
# 517196  2021  365    20  999  99999  999.9
# 517197  2021  365    21  999  99999  999.9
# 517198  2021  365    22  999  99999  999.9
# 517199  2021  365    23  999  99999  999.9
#
# [517200 rows x 6 columns]

# %%
df.index = pd.to_datetime(df["Year"] * 100000 + df["DOY"] * 100 + df["Hour"], format="%Y%j%H")
df = df.drop(columns=["Year", "DOY", "Hour"])

# %%
df
# Out:
#                        R    Dst  F10.7
# 1963-01-01 00:00:00   33     -6  999.9
# 1963-01-01 01:00:00   33     -5  999.9
# 1963-01-01 02:00:00   33     -5  999.9
# 1963-01-01 03:00:00   33     -3  999.9
# 1963-01-01 04:00:00   33     -3  999.9
# ...                  ...    ...    ...
# 2021-12-31 19:00:00  999  99999  999.9
# 2021-12-31 20:00:00  999  99999  999.9
# 2021-12-31 21:00:00  999  99999  999.9
# 2021-12-31 22:00:00  999  99999  999.9
# 2021-12-31 23:00:00  999  99999  999.9
#
# [517200 rows x 3 columns]

# %%
df = df.replace({"R":999,
                 "Dst":99999,
                 "F10.7":999.9}, np.nan)

# %%
df['F10.7'].value_counts()
# Out:
# 69.6     2352
# 68.8     2256
# 69.8     2208
# 69.5     2112
# 69.3     2040
#          ...
# 255.1      24
# 258.1      24
# 296.6      24
# 259.1      24
# 270.4      24
# Name: F10.7, Length: 2010, dtype: int64

# %%
print("Dataframe shape: ", df.shape)
dt = (df.index[-1] - df.index[0])
print("Number of hours between start and end dates: ", dt.total_seconds()/3600 + 1)
# Out:
# Dataframe shape:  (517200, 3)
# Number of hours between start and end dates:  517200.0

# %%
df.plot(figsize=(15,4))
df.plot(subplots=True, figsize=(15,6))
df.plot(y=["R", "F10.7"], figsize=(15,4))
df.plot(x="R", y=["F10.7", "Dst"], style='.')
# Out:
# <AxesSubplot:xlabel='R'>

# %%
df[["F10.7", "R"]].resample("1y").median().plot(figsize=(15,4))
# Out:
# <AxesSubplot:>

# %%
df[["F10.7", "R"]].rolling(24*365).median().plot(figsize=(15,4))
# Out:
# <AxesSubplot:>

# %%
df[["F10.7", "R"]].resample("3y").median().diff().plot(subplots=True, figsize=(15,4))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
Dst_count = df["Dst"].where(df["Dst"]<-100).resample("1y").count()
Dst_count = Dst_count.reindex(df.index, method="bfill")

# %%
df["Dst_count"] = Dst_count
df.plot(y=["R", "Dst_count"], figsize=(15,4));

# %%
# https://en.wikipedia.org/wiki/List_of_solar_cycles
minima = ["1964-10", "1976-03", "1986-09", "1996-08", "2008-12", "2019-12"]
df_daily = df.resample("1D").mean()

def split_into_cycles(df):
    """Returns a list of dataframes, one for each solar cycle"""
    cycles = []
    # Split by solar cycle
    for start, end in zip(minima[0:-1], minima[1:]):
        cycle = df[start:end]
        # Convert from dates to days from minimum
        cycle.index = (cycle.index - cycle.index[0]).days
        # Extend so that each cycle lasts a full 5000 days (filled with nan)
        ix = pd.Int64Index(np.arange(0,5000))
        cycle.reindex(ix)
        cycles.append(cycle)
    return cycles

cycles = split_into_cycles(df_daily)

# %%
fig, axes = plt.subplots(3, 1, figsize=(15,10), sharex=True)
for i, cycle in enumerate(cycles):
    cycle["R"].plot(ax=axes[0], label=f"Cycle {i}")
    cycle["F10.7"].plot(ax=axes[1])
    cycle["Dst_count"].plot(ax=axes[2])
N_cycles = len(cycles)
(sum(cycles)["R"]/N_cycles).plot(ax=axes[0], color="black", label="Mean")
(sum(cycles)["F10.7"]/N_cycles).plot(ax=axes[1], color="black")
(sum(cycles)["Dst_count"]/N_cycles).plot(ax=axes[2], color="black")
axes[0].legend()
axes[0].set_ylabel("Sunspot Number")
axes[1].set_ylabel("F10.7")
axes[2].set_ylabel("Storm rate")
axes[2].set_xlabel("Days since minimum")
for ax in axes:
    ax.grid()

# %%
df.index
# Out:
# DatetimeIndex(['1963-01-01 00:00:00', '1963-01-01 01:00:00',
#                '1963-01-01 02:00:00', '1963-01-01 03:00:00',
#                '1963-01-01 04:00:00', '1963-01-01 05:00:00',
#                '1963-01-01 06:00:00', '1963-01-01 07:00:00',
#                '1963-01-01 08:00:00', '1963-01-01 09:00:00',
#                ...
#                '2021-12-31 14:00:00', '2021-12-31 15:00:00',
#                '2021-12-31 16:00:00', '2021-12-31 17:00:00',
#                '2021-12-31 18:00:00', '2021-12-31 19:00:00',
#                '2021-12-31 20:00:00', '2021-12-31 21:00:00',
#                '2021-12-31 22:00:00', '2021-12-31 23:00:00'],
#               dtype='datetime64[ns]', length=517200, freq=None)

# %%
df
# Out:
#                         R  Dst  F10.7  Dst_count
# 1963-01-01 00:00:00  33.0 -6.0    NaN       38.0
# 1963-01-01 01:00:00  33.0 -5.0    NaN       38.0
# 1963-01-01 02:00:00  33.0 -5.0    NaN       38.0
# 1963-01-01 03:00:00  33.0 -3.0    NaN       38.0
# 1963-01-01 04:00:00  33.0 -3.0    NaN       38.0
# ...                   ...  ...    ...        ...
# 2021-12-31 19:00:00   NaN  NaN    NaN        NaN
# 2021-12-31 20:00:00   NaN  NaN    NaN        NaN
# 2021-12-31 21:00:00   NaN  NaN    NaN        NaN
# 2021-12-31 22:00:00   NaN  NaN    NaN        NaN
# 2021-12-31 23:00:00   NaN  NaN    NaN        NaN
#
# [517200 rows x 4 columns]

# %%
data_2003  = df.loc['2003-11-04 00:00:00':'2003-11-04 23:59:00']

# %%
data_292 = df.loc['2003-10-19 00:00:00':'2003-10-19 23:59:00']

# %%
data_292
# Out:
#                         R   Dst  F10.7  Dst_count
# 2003-10-19 00:00:00  61.0 -21.0  119.4      110.0
# 2003-10-19 01:00:00  61.0 -26.0  119.4      110.0
# 2003-10-19 02:00:00  61.0 -28.0  119.4      110.0
# 2003-10-19 03:00:00  61.0 -26.0  119.4      110.0
# 2003-10-19 04:00:00  61.0 -27.0  119.4      110.0
# 2003-10-19 05:00:00  61.0 -37.0  119.4      110.0
# 2003-10-19 06:00:00  61.0 -39.0  119.4      110.0
# 2003-10-19 07:00:00  61.0 -42.0  119.4      110.0
# 2003-10-19 08:00:00  61.0 -37.0  119.4      110.0
# 2003-10-19 09:00:00  61.0 -32.0  119.4      110.0
# 2003-10-19 10:00:00  61.0 -35.0  119.4      110.0
# 2003-10-19 11:00:00  61.0 -38.0  119.4      110.0
# 2003-10-19 12:00:00  61.0 -40.0  119.4      110.0
# 2003-10-19 13:00:00  61.0 -39.0  119.4      110.0
# 2003-10-19 14:00:00  61.0 -45.0  119.4      110.0
# 2003-10-19 15:00:00  61.0 -40.0  119.4      110.0
# 2003-10-19 16:00:00  61.0 -40.0  119.4      110.0
# 2003-10-19 17:00:00  61.0 -49.0  119.4      110.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data_2003['Dst'])
plt.xticks(rotation = 45)
# Out:
# (array([12360.   , 12360.125, 12360.25 , 12360.375, 12360.5  , 12360.625,
#         12360.75 , 12360.875, 12361.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
data_canada.corrwith(data_292['Dst'],axis =0)
# Out:
# MJdatet   -0.852307
#  Time     -0.853227
#  PRN      -0.036004
#  Az        0.123493
#  Ele      -0.022754
#  Lat       0.172981
#  Lon      -0.178877
#  Stec     -0.734774
#  Vtec     -0.730702
#  S4             NaN
# dtype: float64

# %%
data_omni= pd.read_csv("omni2_all_years.dat",
                 delim_whitespace=True,
                 usecols=[0, 1, 2,19,20,21,24,38, 39, 40,41,42,45,46,47,49, 50],
                 names=["Year", "DOY", "Hour", "Signma Bx","Signma By","Signma Bz","Plasma flow speed","kp","R", "Dst","AE index","Proton flux>1","Proton flux>10" ,"Proton flux>30","Proton flux>60","Ap index","F10.7"])

# %%
data_omni
# Out:
#         Year  DOY  Hour  Signma Bx  Signma By  Signma Bz  Plasma flow speed  \
# 0       1963    1     0      999.9      999.9      999.9             9999.0
# 1       1963    1     1      999.9      999.9      999.9             9999.0
# 2       1963    1     2      999.9      999.9      999.9             9999.0
# 3       1963    1     3      999.9      999.9      999.9             9999.0
# 4       1963    1     4      999.9      999.9      999.9             9999.0
# ...      ...  ...   ...        ...        ...        ...                ...
# 517195  2021  365    19      999.9      999.9      999.9             9999.0
# 517196  2021  365    20      999.9      999.9      999.9             9999.0
# 517197  2021  365    21      999.9      999.9      999.9             9999.0
# 517198  2021  365    22      999.9      999.9      999.9             9999.0
# 517199  2021  365    23      999.9      999.9      999.9             9999.0
#
# ...

# %%
data_omni.index = pd.to_datetime(data_omni["Year"] * 100000 + data_omni["DOY"] * 100 + data_omni["Hour"], format="%Y%j%H")
data_omni = data_omni.drop(columns=["Year", "DOY", "Hour"])

# %%
data_omni
# Out:
#                      Signma Bx  Signma By  Signma Bz  Plasma flow speed  kp  \
# 1963-01-01 00:00:00      999.9      999.9      999.9             9999.0   7
# 1963-01-01 01:00:00      999.9      999.9      999.9             9999.0   7
# 1963-01-01 02:00:00      999.9      999.9      999.9             9999.0   7
# 1963-01-01 03:00:00      999.9      999.9      999.9             9999.0  20
# 1963-01-01 04:00:00      999.9      999.9      999.9             9999.0  20
# ...                        ...        ...        ...                ...  ..
# 2021-12-31 19:00:00      999.9      999.9      999.9             9999.0  99
# 2021-12-31 20:00:00      999.9      999.9      999.9             9999.0  99
# 2021-12-31 21:00:00      999.9      999.9      999.9             9999.0  99
# 2021-12-31 22:00:00      999.9      999.9      999.9             9999.0  99
# 2021-12-31 23:00:00      999.9      999.9      999.9             9999.0  99
#
# ...

# %%
data_omni = data_omni.replace({"R":999,"Signma Bx":999.9,"Signma By":999.9,"Signma Bz":999.9,"Plasma flow speed":9999.0,"kp":99,
                 "Dst":99999,"AE index":9999,"Proton flux>1":99999.99,"Proton flux>10":99999.99,"Proton flux>30":99999.99,"Proton flux>60":99999.99,
                 "F10.7":999.9,"Ap index":999}, np.nan)

# %%
data_omni
# Out:
#                      Signma Bx  Signma By  Signma Bz  Plasma flow speed    kp  \
# 1963-01-01 00:00:00        NaN        NaN        NaN                NaN   7.0
# 1963-01-01 01:00:00        NaN        NaN        NaN                NaN   7.0
# 1963-01-01 02:00:00        NaN        NaN        NaN                NaN   7.0
# 1963-01-01 03:00:00        NaN        NaN        NaN                NaN  20.0
# 1963-01-01 04:00:00        NaN        NaN        NaN                NaN  20.0
# ...                        ...        ...        ...                ...   ...
# 2021-12-31 19:00:00        NaN        NaN        NaN                NaN   NaN
# 2021-12-31 20:00:00        NaN        NaN        NaN                NaN   NaN
# 2021-12-31 21:00:00        NaN        NaN        NaN                NaN   NaN
# 2021-12-31 22:00:00        NaN        NaN        NaN                NaN   NaN
# 2021-12-31 23:00:00        NaN        NaN        NaN                NaN   NaN
#
# ...

# %%
data_292_o = data_omni.loc['2003-10-19 00:00:00':'2003-10-19 23:59:00']

# %%
data_292_o
# Out:
#                      Signma Bx  Signma By  Signma Bz  Plasma flow speed    kp  \
# 2003-10-19 00:00:00        0.4        0.4        1.8              597.0  37.0
# 2003-10-19 01:00:00        1.1        0.9        1.4              596.0  37.0
# 2003-10-19 02:00:00        0.9        1.3        1.5              589.0  37.0
# 2003-10-19 03:00:00        1.6        1.3        2.1              606.0  43.0
# 2003-10-19 04:00:00        1.1        0.6        1.1              596.0  43.0
# 2003-10-19 05:00:00        1.4        3.1        0.8              587.0  43.0
# 2003-10-19 06:00:00        0.8        0.5        1.2              591.0  43.0
# 2003-10-19 07:00:00        0.5        0.6        0.6              590.0  43.0
# 2003-10-19 08:00:00        0.7        1.0        1.8              571.0  43.0
# 2003-10-19 09:00:00        0.7        1.9        1.4              584.0  33.0
# 2003-10-19 10:00:00        1.1        3.3        2.5              602.0  33.0
# ...

# %%
data_us.corrwith(data_292_o['Signma Bx'],axis=0)
# Out:
# MJdatet    0.466090
#  Time      0.466090
#  PRN       0.191925
#  Az       -0.187467
#  Ele       0.233989
#  Lat      -0.071791
#  Lon       0.167659
#  Stec      0.353004
#  Vtec      0.346710
#  S4             NaN
# dtype: float64

# %%
data_eq.corrwith(data_292_o['Signma Bx'],axis=0)
# Out:
# MJdatet    0.469389
#  Time      0.470347
#  PRN      -0.179216
#  Az       -0.330049
#  Ele       0.145651
#  Lat       0.061380
#  Lon       0.562589
#  Stec      0.290957
#  Vtec      0.272890
#  S4             NaN
# dtype: float64

# %%
data_canada.corrwith(data_292_o['Signma Bx'],axis=0)
# Out:
# MJdatet    0.467962
#  Time      0.469453
#  PRN       0.161024
#  Az       -0.180003
#  Ele      -0.249976
#  Lat      -0.079243
#  Lon       0.182594
#  Stec      0.326606
#  Vtec      0.316551
#  S4             NaN
# dtype: float64

# %%
data_canada.corrwith(data_292_o['AE index'],axis=0)
# Out:
# MJdatet    0.608638
#  Time      0.610263
#  PRN      -0.150252
#  Az       -0.221435
#  Ele       0.047741
#  Lat      -0.044874
#  Lon       0.252221
#  Stec      0.699421
#  Vtec      0.721020
#  S4             NaN
# dtype: float64

# %%
plt.plot(data_292_o['AE index'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.plot(data_canada[' Vtec'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
data_canada.corrwith(data_292_o['Proton flux>60'],axis=0)
# Out:
# MJdatet    0.326147
#  Time      0.326147
#  PRN      -0.123399
#  Az       -0.029596
#  Ele      -0.040432
#  Lat       0.094492
#  Lon       0.110490
#  Stec      0.346710
#  Vtec      0.341579
#  S4             NaN
# dtype: float64

# %%
data_canada.corrwith(data_292_o['Ap index'],axis=0)
# Out:
# MJdatet    0.830008
#  Time      0.829629
#  PRN       0.034949
#  Az       -0.052674
#  Ele      -0.006771
#  Lat      -0.119763
#  Lon       0.145793
#  Stec      0.696942
#  Vtec      0.681806
#  S4             NaN
# dtype: float64

# %%
plt.plot(data_292_o['Ap index'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.plot(data_292_o['Proton flux>10'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.16666667, 12344.25      , 12344.33333333, 12344.41666667,
#         12344.5       , 12344.58333333, 12344.66666667, 12344.75      ,
#         12344.83333333]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.plot(data_292_o['Plasma flow speed'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.plot(data_292_o['Dst'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
data_canada.corrwith(data_292_o['Dst'],axis=0)
# Out:
# MJdatet   -0.852307
#  Time     -0.853227
#  PRN      -0.036004
#  Az        0.123493
#  Ele      -0.022754
#  Lat       0.172981
#  Lon      -0.178877
#  Stec     -0.734774
#  Vtec     -0.730702
#  S4             NaN
# dtype: float64

# %%
data_canada.corrwith(data_292_o['Signma By'],axis=0)
# Out:
# MJdatet    0.338000
#  Time      0.339118
#  PRN      -0.019062
#  Az       -0.115826
#  Ele      -0.174344
#  Lat       0.224587
#  Lon       0.153372
#  Stec      0.339317
#  Vtec      0.336104
#  S4             NaN
# dtype: float64

# %%
plt.plot(data_292_o['Signma By'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
data_canada.corrwith(data_292_o['Proton flux>1'],axis=0)
# Out:
# MJdatet   -0.000755
#  Time     -0.003236
#  PRN       0.118168
#  Az        0.163630
#  Ele      -0.229533
#  Lat       0.152546
#  Lon      -0.157732
#  Stec     -0.135810
#  Vtec     -0.161473
#  S4             NaN
# dtype: float64

# %%
plt.plot(data_292_o['Proton flux>1'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
data_canada.corrwith(data_292_o['kp'],axis=0)
# Out:
# MJdatet    0.770784
#  Time      0.770554
#  PRN       0.006698
#  Az       -0.150208
#  Ele      -0.031249
#  Lat      -0.141646
#  Lon       0.229656
#  Stec      0.669382
#  Vtec      0.649188
#  S4             NaN
# dtype: float64

# %%
data_292_o.corrwith(data_292_o['kp'],axis=0)
# Out:
# Signma Bx            0.388699
# Signma By            0.106098
# Signma Bz            0.015627
# Plasma flow speed   -0.013035
# kp                   1.000000
# R                         NaN
# Dst                 -0.736403
# AE index             0.523232
# Proton flux>1        0.043644
# Proton flux>10      -0.163591
# Proton flux>30      -0.143387
# Proton flux>60      -0.112922
# Ap index             0.982177
# F10.7                0.000000
# dtype: float64

# %%
speed = pd.read_csv("speed.csv")

# %%
speed.index = pd.to_datetime(speed["Year"] * 100000 + speed["DOY"] * 100 + speed["Hour"], format="%Y%j%H")
spee = speed.drop(columns=["Year", "DOY", "Hour"])

# %%
spee  = spee.drop(columns = ["Minute"])

# %%
spee.resample("1h").mean()
# Out:
#                            Speed
# 2003-10-19 00:00:00   597.041667
# 2003-10-19 01:00:00   595.958333
# 2003-10-19 02:00:00   588.675000
# 2003-10-19 03:00:00   605.375000
# 2003-10-19 04:00:00   595.825000
# 2003-10-19 05:00:00  8870.675000
# 2003-10-19 06:00:00   594.600000
# 2003-10-19 07:00:00   589.950000
# 2003-10-19 08:00:00   576.025000
# 2003-10-19 09:00:00   578.783333
# 2003-10-19 10:00:00   602.166667
# 2003-10-19 11:00:00   585.158333
# 2003-10-19 12:00:00  8876.616667
# 2003-10-19 13:00:00   596.883333
# 2003-10-19 14:00:00   594.550000
# 2003-10-19 15:00:00   601.600000
# 2003-10-19 16:00:00   601.300000
# 2003-10-19 17:00:00   593.833333
# 2003-10-19 18:00:00   581.608333
# 2003-10-19 19:00:00   593.525000
# 2003-10-19 20:00:00   592.483333
# 2003-10-19 21:00:00   581.325000
# 2003-10-19 22:00:00   592.225000
# 2003-10-19 23:00:00   602.716667

# %%
data_292_o.corrwith(spee['Speed'] , axis=0)
# Out:
# Signma Bx            3.346274e-02
# Signma By            7.566545e-02
# Signma Bz           -2.605264e-02
# Plasma flow speed   -5.912967e-02
# kp                   6.382082e-03
# R                             NaN
# Dst                  2.221676e-03
# AE index            -1.770429e-02
# Proton flux>1       -4.824905e-02
# Proton flux>10       4.517227e-02
# Proton flux>30       4.425934e-02
# Proton flux>60       3.219962e-02
# Ap index            -7.990499e-03
# F10.7                6.551092e-18
# dtype: float64

# %%
omini_file = pd.read_csv(r"file.csv")

# %%
omini_file.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'ut', 'utc', 'SC_IMF', 'SC_Plasma', 'N_IMF',
#        'N_Plasma', 'PercInterp', 'TimeShift', 'RMSTimeShift',
#        'RMSPhaseFrontNorm', 'dTime', 'B', 'BxGSE', 'ByGSE', 'BzGSE', 'ByGSM',
#        'BzGSM', 'RMSSDBScalar', 'RMSSDFieldVector', 'FlowSpeed', 'Vx', 'Vy',
#        'Vz', 'ProtonDensity', 'Temp', 'FlowPressure', 'E', 'Beta', 'MA', 'Xsc',
#        'Ysc', 'Zsc', 'Xbsn', 'Ybsn', 'Zbsn', 'AE', 'AL', 'AU', 'SymD', 'SymH',
#        'AsyD', 'AsyH', 'PC', 'Ms', 'Pflux10', 'Pflux30', 'Pflux60'],
#       dtype='object')

# %%
omini_file.drop(columns = ['Unnamed: 0'])
# Out:
#             Date         ut            utc  SC_IMF  SC_Plasma  N_IMF  \
# 0       20030101   0.000000  464592.000000      60         60      5
# 1       20030101   0.083333  464592.083333      60         60      5
# 2       20030101   0.166667  464592.166667      60         60      5
# 3       20030101   0.250000  464592.250000      60         60      5
# 4       20030101   0.333333  464592.333333      60         60      5
# ...          ...        ...            ...     ...        ...    ...
# 105115  20031231  23.583334  473351.583334      99         99    999
# 105116  20031231  23.666666  473351.666666      99         99    999
# 105117  20031231  23.750000  473351.750000      99         99    999
# 105118  20031231  23.833334  473351.833334      99         99    999
# 105119  20031231  23.916666  473351.916666      99         99    999
#
#         N_Plasma  PercInterp  TimeShift  RMSTimeShift  ...    AU  SymD  SymH  \
# ...

# %%
omini_file['Time'] = omini_file.apply(lambda x :jd_cal(x['utc']),axis=1)

# %%
omini_file
# Out:
#         Unnamed: 0      Date         ut            utc  SC_IMF  SC_Plasma  \
# 0                0  20030101   0.000000  464592.000000      60         60
# 1                1  20030101   0.083333  464592.083333      60         60
# 2                2  20030101   0.166667  464592.166667      60         60
# 3                3  20030101   0.250000  464592.250000      60         60
# 4                4  20030101   0.333333  464592.333333      60         60
# ...            ...       ...        ...            ...     ...        ...
# 105115      105115  20031231  23.583334  473351.583334      99         99
# 105116      105116  20031231  23.666666  473351.666666      99         99
# 105117      105117  20031231  23.750000  473351.750000      99         99
# 105118      105118  20031231  23.833334  473351.833334      99         99
# 105119      105119  20031231  23.916666  473351.916666      99         99
#
#         N_IMF  N_Plasma  PercInterp  TimeShift  ...  SymD  SymH  AsyD  AsyH  \
# ...

# %%
wind = pd.read_csv("wind.csv")

# %%
wind.columns
# Out:
# Index(['BEGI', 'day', 'hr x', '_dot_GSE', 'x_dot_RTN'], dtype='object')

# %%
wind.index = pd.to_datetime(wind["BEGI"] * 100000 + wind["day"] * 100 + wind["hr x"], format="%Y%j%H")
wind = wind.drop(columns=["BEGI", "day", "hr x"])

# %%
wind.resample("1h" ).mean()
# Out:
#                         _dot_GSE   x_dot_RTN
# 2003-10-19 00:00:00  -764.975000  407.846071
# 2003-10-19 01:00:00  -921.128421  219.378596
# 2003-10-19 02:00:00  -934.352679  220.070179
# 2003-10-19 03:00:00  -936.918929  222.614464
# 2003-10-19 04:00:00  -920.739107  206.468750
# 2003-10-19 05:00:00  -924.947895  223.186316
# 2003-10-19 06:00:00  -756.706607  399.545179
# 2003-10-19 07:00:00  -914.996250  200.709107
# 2003-10-19 08:00:00  -911.974107  197.682321
# 2003-10-19 09:00:00  -930.732456  228.995263
# 2003-10-19 10:00:00  -928.617857  214.337857
# 2003-10-19 11:00:00  -747.448929  390.325536
# 2003-10-19 12:00:00  -929.357143  215.045357
# 2003-10-19 13:00:00  -925.483684  223.703509
# 2003-10-19 14:00:00  -930.064464  215.791607
# 2003-10-19 15:00:00  -937.084107  222.756607
# 2003-10-19 16:00:00  -762.680536  405.496250
# 2003-10-19 17:00:00  -912.804211  211.012456
# 2003-10-19 18:00:00  -923.986607  209.672857
# 2003-10-19 19:00:00  -932.001786  217.734286
# ...

# %%
data_canada.corrwith(wind['_dot_GSE'],axis =0)
# Out:
# MJdatet   -0.008388
#  Time     -0.008482
#  PRN       0.004515
#  Az        0.010480
#  Ele       0.012597
#  Lat       0.001688
#  Lon      -0.007910
#  Stec     -0.003117
#  Vtec     -0.002733
#  S4             NaN
# dtype: float64

# %%
data_canada.corrwith(wind['x_dot_RTN'],axis =0)
# Out:
# MJdatet   -0.008602
#  Time     -0.008704
#  PRN       0.004301
#  Az        0.010062
#  Ele       0.011620
#  Lat       0.004551
#  Lon      -0.007024
#  Stec     -0.003022
#  Vtec     -0.002775
#  S4             NaN
# dtype: float64

# %%
data_chur.corrwith(wind['x_dot_RTN'],axis =0)
# Out:
# MJdatet   -0.027575
#  Time     -0.031448
#  PRN       0.003914
#  Az        0.001911
#  Ele      -0.001217
#  Lat       0.000914
#  Lon      -0.006427
#  Stec     -0.016056
#  Vtec     -0.017531
#  S4             NaN
# dtype: float64

# %%
plt.plot(wind['_dot_GSE'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.plot(wind['x_dot_RTN'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
data_canada.columns
# Out:
# Index(['MJdatet', ' Time', ' PRN', ' Az', ' Ele', ' Lat', ' Lon', ' Stec',
#        ' Vtec', ' S4'],
#       dtype='object')

# %%
plt.plot(data_canada[' Vtec'])
plt.xticks(rotation = 45)
# Out:
# (array([12344.   , 12344.125, 12344.25 , 12344.375, 12344.5  , 12344.625,
#         12344.75 , 12344.875, 12345.   ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
